# %% [raw]
# # All_Leave_One_out_expert_based - (random) Max vs increasing CB !
#
# ## support_prim_All_attributes

# %%
# To enable the autocomplete feature based upon clicking the TAB button
# %config IPCompleter.greedy=True
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Rest API call

# %%
import requests
import json

# %%
baseurl = 'http://localhost:8080'
headers = 'application/json'

default_casebase = 'support_prim_cb_latest'
default_concept = 'patient'
default_globalSim='global_sim_1'

default_cases_limit=-1

# %% [markdown]
# ### Get all instances from a given casebase - GET call

# %%
#%%time
casebase_name_gai = 'support_prim_cb_latest'

def getAllInstances():
    url_gai = baseurl+'/instances?casebaseName='+casebase_name_gai
    
    response_gai = requests.get( url=url_gai)
    
    response_json_gai = response_gai.json()
        
    df_response_gai = pd.DataFrame(response_json_gai)
            
    # for sorting
    # df_response = df_response.sort_values(by=['caseID'], ascending=[False])
    
    return df_response_gai

getAllInstances().head();

# %%
instances = getAllInstances()
print( instances.shape)
instances.head()
# Out:
# (258, 58)
#          activity_1 age        bmi body_main      caseID  \
# 0  Slightly reduced  46  25.909456      Back  patient132
# 1  Slightly reduced  31   24.02381      Back  patient253
# 2  Slightly reduced  70  27.774271     Neck   patient131
# 3  Slightly reduced  37  24.280975     Neck   patient252
# 4  Slightly reduced  22  20.438166  Shoulder  patient130
#
#         comob_otherspec        comorbidities  \
# 0                    .;               other;
# 1  Hypofunksjon L3-L5.;               other;
# 2                    .;  dizziness;headache;
# 3                    .;            headache;
# 4                    .;            _unknown_
#
#                             education  \
# 0                         High school
# 1  More than 4 years higher education
# 2  More than 4 years higher education
# 3  More than 4 years higher education
# 4              Primary school or less
#
#                                employment_1 eq5d_questions  \
# 0                    Working and no welfare      _unknown_
# 1                    Working and no welfare      _unknown_
# 2  Other: Student - retiree - non_paid work      _unknown_
# 3                    Working and no welfare      _unknown_
# 4                    Working and no welfare      _unknown_
#
#                    ...                    sbt_sum_1      sleep15D_1 smoking  \
# 0                  ...                            2  sleep normally      No
# 1                  ...                            2  sleep normally      No
# 2                  ...                    _unknown_  sleep normally      No
# 3                  ...                    _unknown_  slight problem      No
# 4                  ...                    _unknown_  slight problem      No
#
#   spadi_total_1   treat_belief                           treatment_12m  \
# 0     _unknown_  totally agree          None treatments last 12 months
# 1     _unknown_  totally agree          None treatments last 12 months
# 2     _unknown_  totally agree  More than 10 treatments last 12 months
# 3     _unknown_  totally agree           1-5 treatments last 12 months
# 4      19.23077  totally agree          None treatments last 12 months
#
#               vital15D_1 walkaid_1 work_ability_1  \
# 0         slightly weary        No              9
# 1  healthy and energetic        No              9
# 2         slightly weary        No              6
# 3       moderately weary        No              9
# 4  healthy and energetic        No              9
#
#                              work_type_1
# 0  Work demands much walking and lifting
# 1                          Mostly seated
# 2                          Mostly seated
# 3                          Mostly seated
# 4              Work demands much walking
#
# [5 rows x 58 columns]

# %%
case_inst = instances.copy(deep=True)
case_inst = case_inst.set_index( case_inst.caseID )
case_inst.drop( columns='caseID', inplace=True)
case_inst.replace('_unknown_', np.NaN, inplace=True)
case_inst['gpe_3'] = case_inst['gpe_3'].astype(int)
case_inst['gpe_3'] = case_inst['gpe_3'].astype(int)
case_inst.gpe_3.dtype
case_inst.head()
# Out:
#                   activity_1 age        bmi body_main       comob_otherspec  \
# caseID
# patient132  Slightly reduced  46  25.909456      Back                    .;
# patient253  Slightly reduced  31   24.02381      Back  Hypofunksjon L3-L5.;
# patient131  Slightly reduced  70  27.774271     Neck                     .;
# patient252  Slightly reduced  37  24.280975     Neck                     .;
# patient130  Slightly reduced  22  20.438166  Shoulder                    .;
#
#                   comorbidities                           education  \
# caseID
# patient132               other;                         High school
# patient253               other;  More than 4 years higher education
# patient131  dizziness;headache;  More than 4 years higher education
# patient252            headache;  More than 4 years higher education
# patient130                  NaN              Primary school or less
#
#                                         employment_1 eq5d_questions ethnicity  \
# caseID
# patient132                    Working and no welfare            NaN   Norway;
# patient253                    Working and no welfare            NaN   Norway;
# patient131  Other: Student - retiree - non_paid work            NaN   Norway;
# patient252                    Working and no welfare            NaN   Norway;
# patient130                    Working and no welfare            NaN   Norway;
#
#                             ...                   sbt_sum_1      sleep15D_1  \
# caseID                      ...
# patient132                  ...                           2  sleep normally
# patient253                  ...                           2  sleep normally
# patient131                  ...                         NaN  sleep normally
# patient252                  ...                         NaN  slight problem
# patient130                  ...                         NaN  slight problem
#
#            smoking spadi_total_1   treat_belief  \
# caseID
# patient132      No           NaN  totally agree
# patient253      No           NaN  totally agree
# patient131      No           NaN  totally agree
# patient252      No           NaN  totally agree
# patient130      No      19.23077  totally agree
#
#                                      treatment_12m             vital15D_1  \
# caseID
# patient132          None treatments last 12 months         slightly weary
# patient253          None treatments last 12 months  healthy and energetic
# patient131  More than 10 treatments last 12 months         slightly weary
# patient252           1-5 treatments last 12 months       moderately weary
# patient130          None treatments last 12 months  healthy and energetic
#
#            walkaid_1 work_ability_1                            work_type_1
# caseID
# patient132        No              9  Work demands much walking and lifting
# patient253        No              9                          Mostly seated
# patient131        No              6                          Mostly seated
# patient252        No              9                          Mostly seated
# patient130        No              9              Work demands much walking
#
# [5 rows x 57 columns]

# %% [markdown]
# ### Retrieve from dependent casebase - GET call

# %%
#http://localhost:8080/expDependentCasebase?casebase=support_prim_cb_latest&concept%20name=patient
#        &amalgamation%20function=global_sim_1&no%20of%20returned%20cases=-1
#        &List%20of%20case%20IDS=patient0%2Cpatient1%2Cpatient2
        
default_list = 'patient0,patient1,patient2'

def executeSimOnAllCases(listOfCases=default_list, cases_limit_rsc=default_cases_limit):
    
    url_rsc = baseurl+'/expDependentCasebase?casebase='+default_casebase+'&concept%20name='+default_concept+'&amalgamation%20function='+default_globalSim+'&no%20of%20returned%20cases='+cases_limit_rsc.__str__()+'&List%20of%20case%20IDS='+listOfCases
    
    response_rsc = requests.get( url=url_rsc)
    
    response_json_rsc = response_rsc.json()
    
    df_response_rsc = pd.DataFrame(response_json_rsc)
    
    return df_response_rsc

# %% [markdown]
# ### Retrieve from independent casebase - GET call

# %%
#http://localhost:8080/expIndependentCasebase?casebase=support_prim_cb_latest&concept%20name=patient
#  &amalgamation%20function=global_sim_1&no%20of%20returned%20cases=-1
#  &List%20of%20case%20IDS%20for%20retrival=patient0%2Cpatient1%2Cpatient2
#  &List%20of%20case%20IDS%20for%20casebase=patient0%2Cpatient1%2Cpatient2%2Cpatient3%2Cpatient4

        
default_retrieval_list = 'patient0,patient1,patient2,patient3'
default_cb_list = 'patient0,patient1,patient2,patient3,patient4,patient5'

def executeSimOnSelectedCases(listOfRetrievalCases=default_retrieval_list, listOfCbCases=default_cb_list, k=default_cases_limit):
    
    url_rsc = baseurl+'/expIndependentCasebase?casebase='+default_casebase+'&concept%20name='+default_concept+'&amalgamation%20function='+default_globalSim+'&no%20of%20returned%20cases='+k.__str__()+'&List%20of%20case%20IDS%20for%20retrival='+listOfRetrievalCases+'&List%20of%20case%20IDS%20for%20casebase='+listOfCbCases
    
    response_rsc = requests.get( url=url_rsc)
    
    response_json_rsc = response_rsc.json()
        
    df_response_rsc = pd.DataFrame(response_json_rsc)

    return df_response_rsc

# %%
re_df = executeSimOnSelectedCases()
re_df.head(7)
# Out:
#           patient0  patient1  patient2  patient3
# patient0  1.000000  0.564811  0.446976  0.444915
# patient1  0.564811  1.000000  0.397998  0.386624
# patient2  0.446976  0.397998  1.000000  0.685504
# patient3  0.444915  0.386624  0.685504  1.000000
# patient4  0.586143  0.569879  0.533033  0.595590
# patient5  0.502262  0.541026  0.602438  0.438993

# %%
all_cases_ids = getAllInstances().caseID.sort_values()
all_cases_ids = all_cases_ids.reset_index(drop=True) # for reindexing and drop for droping the current index
all_cases_ids;

# %% [markdown]
# ## Create the retrival set of cases

# %%
retrieval_set = all_cases_ids[0:10]
retrieval_set = retrieval_set.tolist()
retrieval_set;

# %%
loo_casebase = all_cases_ids[:].tolist()
loo_casebase;

# %% [markdown]
# ## Create casebase leaving retrival set

# %%
import random
def loo_query_n_cb( case_ids_lqc=all_cases_ids, query_size=50):
    query_cases = random.sample( set(case_ids_lqc), k=query_size)
    cb_casses = [x for x in case_ids_lqc if x not in query_cases]
    return query_cases, cb_casses, ','.join(query_cases), ','.join(cb_casses)

# %%
qList, cList, queries, casebase, = loo_query_n_cb( query_size=52)
#print(len(qList))
#print(len( casebase.split(',')))
df_q_result = executeSimOnSelectedCases( listOfRetrievalCases=queries, listOfCbCases=casebase, k=1)
df_q_result.dropna( how='all');

# %%
df_q_result = executeSimOnSelectedCases( listOfRetrievalCases=queries, listOfCbCases=casebase, k=1)
df_q_result;

# %%
def extract_data(data, x):
    query_id = x
    sim_score = data[x].max().round(2)
    case_id = data[x].idxmax()
    q_row = case_inst.loc[query_id,:]
    c_row = case_inst.loc[case_id,:]
    q_id = q_row.id
    c_id = c_row.id
    q_gpe = q_row.gpe_3
    c_gpe = c_row.gpe_3
    q_c_distance = q_gpe - c_gpe
    #print(q_id,'\n')
    return query_id, case_id, sim_score, q_id, c_id, q_gpe, c_gpe, q_c_distance

# %%
max_sim_id = lambda x : extract_data( df_q_result,x)
full = list(map(max_sim_id, df_q_result.columns))
full = pd.DataFrame(full, columns=['quary_id', 'case_id','sim','q_id', 'c_id','query_gpe','case_gpe','error'])
full
# Out:
#       quary_id     case_id   sim q_id c_id  query_gpe  case_gpe  error
# 0   patient100  patient223  0.75  209  427          1         1      0
# 1   patient103  patient102  0.79  214  213          2         3     -1
# 2   patient106  patient105  0.69  218  216          3         3      0
# 3   patient110   patient61  0.75  231  126          3         2      1
# 4   patient112  patient147  0.71  234  302          2         1      1
# 5   patient118  patient237  0.63  241  466          3         2      1
# 6    patient12   patient16  0.68   22   26          2         3     -1
# 7   patient122   patient47  0.68  257   89          4         3      1
# 8   patient127   patient74  0.73  269  149          2         1      1
# 9    patient14  patient105  0.72   24  216          2         3     -1
# 10  patient142  patient166  0.71  294  323          2         2      0
# 11  patient146   patient16  0.63  301   26          4         3      1
# 12  patient150  patient256  0.75  305  503          1         1      0
# 13  patient157  patient178  0.75  314  338          2         2      0
# 14  patient167  patient215  0.75  324  411          2         2      0
# 15   patient17   patient18  0.68   27   28          3         2      1
# 16  patient170   patient13  0.81  327   23          2         2      0
# 17  patient171  patient166  0.70  328  323          1         2     -1
# 18  patient183  patient179  0.72  348  339          3         3      0
# 19  patient184  patient180  0.81  350  342          3         3      0
# 20  patient190  patient187  0.72  358  355          3         4     -1
# 21  patient193  patient236  0.68  362  465          1         3     -2
# 22  patient197   patient86  0.74  371  189          1         4     -3
# 23  patient198  patient152  0.66  373  307          4         3      1
# 24  patient201  patient248  0.65  376  487          2         5     -3
# 25  patient202   patient16  0.70  377   26          6         3      3
# 26  patient209  patient174  0.67  387  331          1         2     -1
# 27   patient21   patient36  0.70   31   69          3         3      0
# 28  patient218   patient29  0.66  414   50          3         3      0
# 29  patient219   patient97  0.72  415  203          2         2      0
# 30   patient22  patient143  0.67   32  296          3         2      1
# 31  patient227   patient47  0.70  443   89          2         3     -1
# 32  patient232  patient169  0.65  454  326          2         5     -3
# 33  patient238  patient236  0.81  468  465          3         3      0
# 34  patient246   patient86  0.76  483  189          2         4     -2
# 35   patient33  patient143  0.69   61  296          3         2      1
# 36    patient4    patient7  0.69   12   16          2         3     -1
# 37   patient40   patient42  0.76   75   79          3         4     -1
# 38   patient44  patient145  0.65   86  300          2         2      0
# 39   patient45  patient222  0.77   87  426          3         2      1
# 40    patient5   patient92  0.75   14  197          2         2      0
# 41   patient52   patient73  0.71   96  148          1         1      0
# 42   patient62  patient222  0.71  127  426          3         2      1
# 43   patient71  patient111  0.67  146  232          3         2      1
# 44   patient76  patient114  0.67  152  236          2         1      1
# 45   patient78  patient229  0.63  154  448          3         3      0
# 46   patient79  patient187  0.74  156  355          2         4     -2
# 47    patient8   patient10  0.67   17   20          3         3      0
# 48   patient81  patient139  0.76  161  289          2         2      0
# 49   patient85   patient50  0.73  188   93          2         2      0
# 50   patient90  patient245  0.68  195  482          2         1      1
# 51   patient94  patient143  0.69  199  296          1         2     -1

# %%
def mse (data):
    m = np.square(data.query_gpe - data.case_gpe)/2
    #print(m)
    return m

# %%
def me (data):
    m = (data.query_gpe - data.case_gpe)/2
    #print(m)
    return m

# %%
temp = mse(full)
error = temp.values
error[::-1].sort()
error
plt.plot(error)

# %%
print( lambda x,y : full[[]])
# Out:
# <function <lambda> at 0x1187eb510>

# %%
df_sim_error_dist = full[['sim','error']]
df_sim_error_dist.error = (df_sim_error_dist.error**2)/2
mi = df_sim_error_dist.error.min()
mx = df_sim_error_dist.error.max()
df_sim_error_dist.error = df_sim_error_dist.error/(mx-mi) # normalized
# Out:
# /Users/amar/Software/python/anaconda/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df_sim_error_dist.sort_values( by='sim', ascending=False, inplace=True)
df_sim_error_dist = df_sim_error_dist.set_index( df_sim_error_dist.sim )
df_sim_error_dist.plot()
# Out:
# /Users/amar/Software/python/anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def itrate():
    qList, cList, queries, casebase, = loo_query_n_cb( query_size=52)
    #print(qList)
    #print(len( casebase.split(',')))
    df_q_result = executeSimOnSelectedCases( listOfRetrievalCases=queries, listOfCbCases=casebase, k=1)
    df_q_result.dropna( how='all')
    
    max_sim_id = lambda x : extract_data( df_q_result,x)
    full = list(map(max_sim_id, df_q_result.columns))
    full = pd.DataFrame(full, columns=['quary_id', 'case_id','sim','q_id', 'c_id','query_gpe','case_gpe','error'])
    
    df_sim_error_dist = full[['sim','error']]
    df_sim_error_dist.error = (df_sim_error_dist.error**2)/2
    mi = df_sim_error_dist.error.min()
    mx = df_sim_error_dist.error.max()
    df_sim_error_dist.error = df_sim_error_dist.error/(mx-mi) # normalized
    
    df_sim_error_dist.sort_values( by='sim', ascending=False, inplace=True)
    df_sim_error_dist = df_sim_error_dist.set_index( df_sim_error_dist.sim )
    df_sim_error_dist.plot()
    return df_sim_error_dist

# %%
df_1 = itrate()
df_2 = itrate()
df_3 = itrate()
df_4 = itrate()
df_5 = itrate()
df_6 = itrate()
df_7 = itrate()
df_8 = itrate()
df_9 = itrate()
df_10 = itrate()
# Out:
# /Users/amar/Software/python/anaconda/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /Users/amar/Software/python/anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
